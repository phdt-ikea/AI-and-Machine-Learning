# %% [markdown]
# # Practice activity: Analyzing a dataset and implementing a neural network for deep learning analysis
# ## Introduction
# This activity will guide you through the process of using deep learning to solve a real-world problem using a dataset. By the end of the activity ,you should be able to apply neural networks to various types of data for analysis and prediction.
#
# By the end of this activity, you’ll be able to:
# * Analyze a given dataset to understand its structure and features.
# * Implement a deep learning neural network for analysis and prediction.
# * Evaluate the results of the neural network model to understand its performance.
#
# ## Step-by-step instructions
# ### Step 1: Analyzing the dataset
# #### Objective
# You’ll begin by analyzing the dataset to understand its structure, the features it contains, and the target variable you want to predict.
#
# #### Dataset
# For this activity, we’ll use the Pima Indians diabetes dataset (or another dataset provided by your instructor). This dataset contains several medical predictor variables and a target variable indicating whether a patient has diabetes.
#
# #### Steps
# 1. Load the dataset
# You can load the dataset using pandas. The dataset consists of medical attributes such as glucose level, insulin, body mass index (BMI), age, and the target variable (1 for diabetes, 0 for no diabetes).

# %%
import pandas as pd

# Load the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
data = pd.read_csv(url, names=columns)

# Display the first few rows of the dataset
print(data.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 2. Perform basic data analysis
# Explore the dataset by checking for missing values, noting statistical summaries, and understanding the distribution of the features.

# %%
# Check for missing values
print(data.isnull().sum())

# Display basic statistics
print(data.describe())

# Check the distribution of the target variable
print(data['Outcome'].value_counts())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Preprocessing the data
# #### Objective
# Before implementing the neural network, the data must be preprocessed. This includes normalizing the features and splitting the dataset into training and test sets.
#
# #### Steps
# 1. Feature scaling
# Neural networks perform better when the features are scaled to a similar range. We’ll scale the feature values to a range between 0 and 1 using MinMaxScaler.

# %%
from sklearn.preprocessing import MinMaxScaler

# Separate features and target variable
X = data.drop('Outcome', axis=1)
y = data['Outcome']

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 2. Splitting the dataset
# Split the dataset into training and testing sets. Typically, 80 percent of the data is used for training and 20 percent for testing.

# %%
from sklearn.model_selection import train_test_split

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Step 3: Implementing a deep learning neural network
# #### Objective
# You will implement a deep learning neural network using TensorFlow’s Keras API to predict whether a patient has diabetes.
#
# #### Steps
# 1. Build the neural network
# We’ll create a simple feedforward neural network with two hidden layers.
# 2. Compile the model
# Compile the model using binary cross-entropy loss (suitable for binary classification) and the adaptive moment estimation (Adam) optimizer.
# 3. Train the model
# Train the model using the training dataset, and validate its performance using the test dataset. We’ll train for 50 epochs.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Build the neural network model
model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),  # First hidden layer
    layers.Dense(32, activation='relu'),  # Second hidden layer
    layers.Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6498 - loss: 0.6663 - val_accuracy: 0.6429 - val_loss: 0.6583
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6531 - loss: 0.6470 - val_accuracy: 0.6429 - val_loss: 0.6473
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6531 - loss: 0.6310 - val_accuracy: 0.6494 - val_loss: 0.6300
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6596 - loss: 0.6174 - val_accuracy: 0.6688 - val_loss: 0.6185
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6743 - loss: 0.6022 - val_accuracy: 0.6818 - val_loss: 0.6045
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6808 - loss: 0.5866 - val_accuracy: 0.6753 - val_loss: 0.5933
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6857 - loss: 0.5765 - val_accuracy: 0.6818 - val_loss: 0.5847
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7182 - loss: 0.5625 - val_accuracy: 0.7013 - val_loss: 0.5798
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7068 - loss: 0.5576 - val_accuracy: 0.6948 - val_loss: 0.5735
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7264 - loss: 0.5444 - val_accuracy: 0.7143 - val_loss: 0.5613
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7313 - loss: 0.5386 - val_accuracy: 0.7078 - val_loss: 0.5554
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7362 - loss: 0.5248 - val_accuracy: 0.7078 - val_loss: 0.5491
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7476 - loss: 0.5170 - val_accuracy: 0.7338 - val_loss: 0.5376
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7443 - loss: 0.5118 - val_accuracy: 0.7597 - val_loss: 0.5370
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7606 - loss: 0.5009 - val_accuracy: 0.7273 - val_loss: 0.5315
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7508 - loss: 0.4964 - val_accuracy: 0.7338 - val_loss: 0.5300
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7655 - loss: 0.4895 - val_accuracy: 0.7208 - val_loss: 0.5309
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7655 - loss: 0.4838 - val_accuracy: 0.7792 - val_loss: 0.5219
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7704 - loss: 0.4733 - val_accuracy: 0.7597 - val_loss: 0.5269
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7720 - loss: 0.4701 - val_accuracy: 0.7273 - val_loss: 0.5388
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7720 - loss: 0.4747 - val_accuracy: 0.7532 - val_loss: 0.5246
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7818 - loss: 0.4615 - val_accuracy: 0.7597 - val_loss: 0.5157
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7785 - loss: 0.4590 - val_accuracy: 0.7532 - val_loss: 0.5188
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7736 - loss: 0.4544 - val_accuracy: 0.7338 - val_loss: 0.5233
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7720 - loss: 0.4578 - val_accuracy: 0.7273 - val_loss: 0.5249
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7964 - loss: 0.4478 - val_accuracy: 0.7662 - val_loss: 0.5141
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7769 - loss: 0.4494 - val_accuracy: 0.7338 - val_loss: 0.5171
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7818 - loss: 0.4437 - val_accuracy: 0.7338 - val_loss: 0.5171
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7883 - loss: 0.4412 - val_accuracy: 0.7597 - val_loss: 0.5142
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7801 - loss: 0.4398 - val_accuracy: 0.7338 - val_loss: 0.5249
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7785 - loss: 0.4446 - val_accuracy: 0.7792 - val_loss: 0.5161
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7834 - loss: 0.4367 - val_accuracy: 0.7338 - val_loss: 0.5239
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7866 - loss: 0.4353 - val_accuracy: 0.7143 - val_loss: 0.5258
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7883 - loss: 0.4363 - val_accuracy: 0.7338 - val_loss: 0.5296
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7834 - loss: 0.4388 - val_accuracy: 0.7727 - val_loss: 0.5201
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7883 - loss: 0.4327 - val_accuracy: 0.7792 - val_loss: 0.5109
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7899 - loss: 0.4288 - val_accuracy: 0.7403 - val_loss: 0.5204
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7834 - loss: 0.4277 - val_accuracy: 0.7338 - val_loss: 0.5225
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7964 - loss: 0.4277 - val_accuracy: 0.7987 - val_loss: 0.5184
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7883 - loss: 0.4406 - val_accuracy: 0.7338 - val_loss: 0.5286
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7948 - loss: 0.4281 - val_accuracy: 0.7338 - val_loss: 0.5337
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7915 - loss: 0.4203 - val_accuracy: 0.7922 - val_loss: 0.5260
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7932 - loss: 0.4325 - val_accuracy: 0.7338 - val_loss: 0.5279
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7834 - loss: 0.4284 - val_accuracy: 0.7273 - val_loss: 0.5360
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8078 - loss: 0.4224 - val_accuracy: 0.7922 - val_loss: 0.5340
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7687 - loss: 0.4401 - val_accuracy: 0.7987 - val_loss: 0.5163
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7980 - loss: 0.4181 - val_accuracy: 0.7468 - val_loss: 0.5205
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7866 - loss: 0.4276 - val_accuracy: 0.7403 - val_loss: 0.5348
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7801 - loss: 0.4283 - val_accuracy: 0.7143 - val_loss: 0.5387
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7801 - loss: 0.4309 - val_accuracy: 0.7597 - val_loss: 0.5159

# %% [markdown]
# ### Step 4: Evaluating the results
# #### Objective
# Evaluate the model's performance using accuracy and visualize the training process with loss and accuracy plots.
#
# #### Steps
# 1. Evaluate the model on test data
# After training, evaluate the model’s accuracy on the test dataset.
# 2. Plot accuracy and loss
# Use Matplotlib to plot the model's training and validation accuracy and loss over time to observe its performance.

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy}')

import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7597 - loss: 0.5159
# Test Accuracy: 0.7597402334213257

# %% [markdown]
# ## Deliverables
# By the end of this activity, you should create:
# * Your code for data analysis, preprocessing, building, and training the neural network.
# * A report (300–400 words) summarizing the results, including:
#     * The model’s test accuracy.
#     * Insights gained from the accuracy and loss plots.
#     * Any challenges or observations during the training process.
#
# ## Conclusion
# In this activity, you learned how to analyze a dataset, preprocess the data, implement a deep learning neural network, and evaluate the model’s performance. This process is crucial for applying deep learning to solve real-world problems across various industries, from healthcare to finance.
